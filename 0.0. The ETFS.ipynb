# %% [markdown]
# # EU 탄소배출권 가격 예측 모델 개발
#
# ### 0. 서론 배경 및 목적
#
# - motiviation
#     - 최근 한국 금융시장에 도입된 탄소배출권 ETF의 인기
#     - 탄소국경세(CBAM), fit for 55 등 유럽 탄소 규제 강화안 발표
# - background
#     - 탄소배출권 거래제 이론
#     - 전세계 탄소배출권 제도 운영 현황
#     - 탄소 관련 금융 상품
#
# ###  2. 본론1- 관련 금융상품 탐색 및 수익률 분석
#
# - 유럽탄소배출권 선물 및 관련 ETF 8에 대한 기술통계 분석
# - 유럽탄소배출권 선물 및 관련 ETF 8에 대한 수익률 분석
#
# ###  3. 본론2 - 유럽탄소배출권 선물 가격 예측 모델 개발
#
# - 유럽탄소배출권 선물 가격 예측을 위한 머신러닝/딥러닝 모델 개발
#
# ###  4. 결론 결과 및 시사점

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import FinanceDataReader as fdr

# %% [markdown]
# # 0. 탄소배출권 관련 데이터 탐색
# * 유럽 탄소배출권 선물: 'CFI2Z1'
# * 배출권 추종 ETF : 'KRBN', 'KEUA','KCCA'
# * Green Funds 추종 대표 ETF : 'GRNB', 'BGRN'
# * 탄소중립대표 지수 추종 및 기업 ETF : 'LOWC', 'LCTU' ,'LCTD'
# * 국내시장 유럽탄소배출권 선물 추종 대표  ETF: 'kodex_eu'
# * 출처:https://carboncredits.com/how-to-invest-in-carbon-credits-carbon-etfs-and-carbon-stocks/

# %% [markdown]
# ### 0-0 .  데이터 호출

# %%
eua = fdr.DataReader('CFI2Z1','2000','2022')
krbn = fdr.DataReader('KRBN','2000','2022') 
keua = fdr.DataReader('KEUA','2000','2022') 
kcca = fdr.DataReader('KCCA','2000','2022') 
grnb = fdr.DataReader('GRNB','2000','2022')
bgrn = fdr.DataReader('BGRN','2000','2022') 
lowc = fdr.DataReader('LOWC','2000','2022') 
lctu = fdr.DataReader('LCTU','2000','2022') 
lctd = fdr.DataReader('LCTD','2000','2022') 
kodex_eu = fdr.DataReader('400570','2000','2022')

# %% [markdown]
# ### 0-1. 기술통계분석

# %%
eua.tail(1)
# Out:
#             Close   Open   High    Low  Volume  Change
# Date
# 2021-12-31   80.9  79.98  81.25  79.55  3690.0  0.0106

# %%
carbons= [eua, krbn, keua, kcca, grnb, bgrn, lowc, lctu, lctd, kodex_eu]

# %%
cbns = ['eua', 'krbn', 'keua', 'kcca', 'grnb', 'bgrn', 'lowc', 'lctu', 'lctd', 'kodex_eu']

# %%
# 종가

# %%
plt.figure(figsize =(15,45))
for i, carbon in enumerate(carbons):
    plt.subplot(10,2,i+1)
    carbon.Close.plot()
    plt.title(cbns[i], fontsize=13)
    plt.grid(which='both')
    plt.xticks(rotation =30)
    
plt.subplots_adjust(left=0.12, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace= 1.25)


plt.show()
# 종가 전체 시각화

# %%
plt.figure(figsize =(15,45))
for i, carbon in enumerate(carbons):
    plt.subplot(10,2,i+1)
    carbon.Close[-60:].plot(kind='line', color='crimson')
    plt.grid(which='both')
    plt.xticks(rotation =30)
    plt.title(cbns[i], fontsize=13)

plt.subplots_adjust(left=0.12, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace= 1.25)
    
plt.show()
# 종가 최근 60일

# %%
# 거래량

# %%
plt.figure(figsize =(15,40))
for i, carbon in enumerate(carbons):
    plt.subplot(10,2,i+1)
    carbon.Volume.plot(kind='area')
    plt.title(cbns[i], fontsize =13)
    plt.grid(which='both')
    plt.xticks(rotation =30)
    
plt.subplots_adjust(left=0.12, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace= 1.25)

plt.show()
# 거래량 전체 시각화

# %%
plt.figure(figsize =(15,45))
for i, carbon in enumerate(carbons):
    plt.subplot(10,2,i+1)
    carbon.Volume[-60:].plot(kind='area', color = 'violet')
    plt.title(cbns[i], fontsize =13)
    plt.grid(which='both')
    plt.xticks(rotation =30)
    
plt.subplots_adjust(left=0.12, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace= 1.25)

plt.show()
# 거래량 최근 60일

# %%
# 거래량 평균 바 그래프
avg_vol = {}
for i, carbon in enumerate(carbons):
    avg_vol[cbns[i]]= carbon.Volume.mean()
    
avg_vol60 = {}
for i, carbon in enumerate(carbons):
    avg_vol60[cbns[i]]= carbon.Volume[-60:].mean()

# %%
plt.figure(figsize =(10, 5))

plt.bar(avg_vol.keys(), avg_vol.values(), color='orange', alpha=0.5)
plt.scatter(avg_vol60.keys(), avg_vol60.values(), color='red', marker='*', alpha=1)
plt.grid(which='both')
plt.xticks(rotation =30)
plt.title('Volumn_AVG')    

plt.show()

# %%
for i, carbon in enumerate(carbons):
    print(cbns[i])
    print(carbon.describe().T)
    print('------------------------')
# Out:
# eua
#          count         mean          std     min       25%       50%  \
# Close   2674.0    16.358485    15.133207   2.700    5.9100    8.1700
# Open    2674.0    16.320213    15.097795   2.710    5.9600    8.2100
# High    2674.0    16.574177    15.411322   2.900    6.0025    8.2600
# Low     2674.0    16.073646    14.819742   2.490    5.8800    8.1700
# Volume  2674.0  5254.869110  9412.127959  10.000  190.0000  975.0000
# Change  2674.0     0.000242     0.048354  -0.413   -0.0153    0.0003
#
#               75%         max
# Close     24.1875     89.6000
# Open      24.1775     89.7100
# High      24.4900     90.6900
# Low       23.8100     85.0700
# Volume  4777.5000  80530.0000
# Change     0.0176      0.4986
# ------------------------
# krbn
#         count           mean            std       min           25%  \
# Close   358.0      31.644972       8.973742   18.9600     23.090000
# Open    358.0      31.666927       8.943371   19.1000     23.130000
# High    358.0      31.893324       9.034097   19.1000     23.300000
# Low     358.0      31.368687       8.842940   18.8800     22.890000
# Volume  358.0  279389.106145  315738.589857  110.0000  10962.500000
# Change  358.0       0.002817       0.020887   -0.0955     -0.007575
#
#                  50%           75%           max
# Close       30.12500      37.87750  5.474000e+01
# Open        30.04500      37.94000  5.376000e+01
# High        30.23500      37.96750  5.479000e+01
# Low         29.90000      37.54000  5.350000e+01
# Volume  179805.00000  461835.00000  1.910000e+06
# Change       0.00285       0.01435  6.060000e-02
# ------------------------
# keua
#         count          mean           std        min        25%        50%  \
# Close    61.0     26.739344      3.563896    21.8400    23.3900    25.9200
# Open     61.0     26.818361      3.481867    21.9300    23.5700    25.9600
# High     61.0     27.045574      3.605345    21.9500    23.6300    26.1100
# Low      61.0     26.448197      3.417589    21.6700    23.3100    25.6700
# Volume   61.0  16440.655738  19551.823263  1680.0000  5980.0000  9320.0000
# Change   61.0      0.004061      0.039701    -0.1392    -0.0132     0.0034
#
#                75%          max
# Close      30.3800      34.6700
# Open       30.1400      34.5600
# High       30.6600      34.9100
# Low        29.7700      34.0700
# Volume  21370.0000  135890.0000
# Change      0.0286       0.1146
# ------------------------
# kcca
#         count           mean            std         min       25%         50%  \
# Close    61.0      27.050164       1.950784     24.0800     25.50     26.8200
# Open     61.0      27.084754       1.958062     24.0200     25.30     26.8900
# High     61.0      27.443934       1.971211     24.4100     25.94     27.0100
# Low      61.0      26.666885       1.933710     23.4000     25.06     26.2700
# Volume   61.0  121800.819672  112255.179870  15050.0000  53950.00  90260.0000
# Change   61.0       0.001844       0.029770     -0.1266     -0.01      0.0038
#
#                 75%          max
# Close       28.1300      31.3900
# Open        28.0500      31.4100
# High        28.3500      31.5200
# Low         27.7500      30.8300
# Volume  136410.0000  550610.0000
# Change       0.0166       0.0735
# ------------------------
# grnb
#          count         mean           std      min        25%      50%  \
# Close   1201.0    26.705545      0.763501  24.6300    26.0500    26.82
# Open    1201.0    26.707685      0.765089  24.6400    26.0400    26.82
# High    1201.0    26.738968      0.762459  24.6600    26.0800    26.85
# Low     1201.0    26.673006      0.767131  24.6300    26.0100    26.79
# Volume  1201.0  7867.918401  11024.218007  10.0000  1680.0000  4270.00
# Change  1201.0     0.000066      0.002975  -0.0164    -0.0015     0.00
#
#               75%          max
# Close     27.2500      28.0800
# Open      27.2600      28.0900
# High      27.3000      28.0900
# Low       27.2300      28.0400
# Volume  9650.0000  100510.0000
# Change     0.0017       0.0179
# ------------------------
# bgrn
#         count          mean           std       min        25%         50%  \
# Close   742.0     54.576442      1.236708   50.1600    54.1200     54.8100
# Open    742.0     54.597426      1.245941   50.1700    54.1125     54.8100
# High    742.0     54.652480      1.246038   50.1900    54.1825     54.8800
# Low     742.0     54.514353      1.232306   50.1600    54.0600     54.7400
# Volume  742.0  16039.056604  19488.865839  100.0000  4590.0000  11295.0000
# Change  742.0      0.000106      0.002635   -0.0172    -0.0012      0.0002
#
#                75%          max
# Close      55.4900      56.3300
# Open       55.5000      58.8600
# High       55.5600      58.8600
# Low        55.4275      56.2500
# Volume  20840.0000  230770.0000
# Change      0.0016       0.0092
# ------------------------
# lowc
#          count         mean           std     min       25%      50%  \
# Close   1546.0    92.337083     17.692623  63.120   78.8925   89.545
# Open    1546.0    92.357749     17.699492  62.890   78.8300   89.475
# High    1546.0    92.554288     17.734789  63.280   78.9650   89.730
# Low     1546.0    92.141100     17.655266  62.430   78.7400   89.255
# Volume  1546.0  4118.589909  27487.156122  20.000  470.0000  930.000
# Change  1546.0     0.000431      0.011255  -0.102   -0.0040    0.001
#
#               75%           max
# Close     99.1875      134.6800
# Open      99.1675      134.8400
# High      99.3975      134.8600
# Low       98.8275      134.5300
# Volume  1910.0000  1000000.0000
# Change     0.0057        0.0918
# ------------------------
# lctu
#         count          mean            std       min        25%         50%  \
# Close   186.0     50.742903       2.144187   46.5800    48.8550    50.73000
# Open    186.0     50.760269       2.153420   46.5900    48.8625    50.74000
# High    186.0     50.904140       2.145331   47.2000    48.9725    50.87000
# Low     186.0     50.573441       2.156984   46.5000    48.7150    50.57000
# Volume  186.0  41730.860215  245558.298531  440.0000  2545.0000  4540.00000
# Change  186.0      0.000777       0.007906   -0.0268    -0.0038     0.00135
#
#                 75%           max
# Close     52.310000  5.446000e+01
# Open      52.330000  5.466000e+01
# High      52.530000  5.474000e+01
# Low       52.130000  5.440000e+01
# Volume  9420.000000  2.500000e+06
# Change     0.005075  2.130000e-02
# ------------------------
# lctd
#         count         mean           std     min       25%        50%  \
# Close   185.0    48.029838      0.874926  45.990   47.4400    48.1800
# Open    185.0    48.011946      0.883508  45.790   47.3400    48.1900
# High    185.0    48.103838      0.853175  45.990   47.4800    48.2900
# Low     185.0    47.932919      0.907543  45.790   47.2900    48.1000
# Volume  185.0  4166.540541  14637.929214  10.000  410.0000  1310.0000
# Change  185.0     0.000130      0.008100  -0.026   -0.0044     0.0002
#
#               75%          max
# Close     48.7200      49.5000
# Open      48.7100      49.4800
# High      48.7400      49.5000
# Low       48.6600      49.4400
# Volume  3570.0000  178850.0000
# Change     0.0051       0.0183
# ------------------------
# kodex_eu
#         count           mean            std           min            25%  \
# Open     64.0   11041.640625    1458.430352   8945.000000    9655.000000
# High     64.0   11084.375000    1461.101047   9025.000000    9675.000000
# Low      64.0   10983.671875    1459.032415   8880.000000    9590.000000
# Close    64.0   11040.312500    1469.250396   9025.000000    9617.500000
# Volume   64.0  342740.750000  179447.395491  79800.000000  234563.500000
# Change   63.0       0.004238       0.033823     -0.115044      -0.014047
#
#                   50%            75%            max
# Open     10702.500000   12331.250000   14255.000000
# High     10802.500000   12365.000000   14390.000000
# Low      10700.000000   12285.000000   14255.000000
# Close    10747.500000   12330.000000   14370.000000
# Volume  298319.000000  384008.250000  996860.000000
# Change       0.007299       0.028142       0.062917
# ------------------------

# %% [markdown]
# - grnb, lowc, lctd 평균거래량 1만 이하
# - keua, kcca, kodex_eu 는 상장한지 약 2개월밖에 안됨
# - grnb, lctd는 표준편차 낮음(변동성 거의 없다는 의미)

# %% [markdown]
# ### 0-2. 상관관계 분석

# %%
# 최근 종가
close_all = {}
for i, carbon in enumerate(carbons):
    close_all[cbns[i]]= carbon.Close[-60:]

plt.figure(figsize=(7,7))
upp_mat = np.triu(pd.DataFrame(close_all).dropna().corr())
sns.heatmap(pd.DataFrame(close_all).dropna().corr(),  vmin=-1, vmax= +1, annot=True, cmap = 'coolwarm', mask = upp_mat)
plt.show()

# %% [markdown]
# - 유럽탄소배출권선물가격(EUA)
#     - 양의 상관관계 : keua(1), krbn(0.98), kodex_eu(0.96), bgrn(0.72)
#     - 음의 상관관계 : lctd(-0.6), grnb( -0.34)
# - KODEX유럽탄소배출권선물ICD(kodex_eu)
#     - 양의 상관관계 : eua(0.96), keua(0.95), krbn(0.93), bgrn(0.74)
#     - 음의 상관관계 : lctd(-0.66), grbn(-0.26)
# - grnb/bgrn은 둘다 친환경프로젝트 투자 관련 제품이지만 서로 성격 달리함
#     - grnb는 eua와 음, bgrn은 양의 상관관계
#     - bgrn은 전세계 600여개 친환경프로젝트 투자 관련 인덱스 추종 상품
#     - grnb는 전세계 300여개 친환경프로젝트 중 미화(dollar)로 계상된 투자 인덱스 추종상품
# - 캘리포니아 탄소배출권 선물(KCCA)
#     - 양의 상관관계 : lctu(0.78),lowc(0.77),lctd(0.56)
#     - 음의 상관관계 : grnb(-0.53)
#     - EUA(0.0016)으로 유럽탄소배출권과는 패턴 다름

# %%
plt.figure(figsize=(7,7))
sns.heatmap(pd.DataFrame(close_all).dropna().corr()[['eua']],  vmin=-1, vmax= +1, annot=True, cmap = 'coolwarm')
plt.show()

# %%
# 최근 거래량
volume_all = {}
for i, carbon in enumerate(carbons):
    volume_all[cbns[i]]= carbon.Volume[-60:]

plt.figure(figsize=(7,7))
upp_mat = np.triu(pd.DataFrame(volume_all).dropna().corr())
sns.heatmap(pd.DataFrame(volume_all).dropna().corr(), vmin=-1, vmax= +1, annot=True, cmap = 'coolwarm', mask = upp_mat)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - eua
#     - 양의 상관관계 : kodex(0.74), keua(0.67), krbn(0.58)
#     - 음의 상관관계 : lowc(-29)
# - 이외의 상관관계는 종가의 상관과계보다 약함
# - kcca는 별도의 거래량패턴 가짐
# - 가격결정은 공통성분(eua)에 기원하지만, 각 고객이 상이하여 다른 패턴이 나오는 것으로 추측됨
#     - 유럽내 ets대상 배출기업(eua), 미국장(krbn/keua), 한국장(kodex)

# %%
plt.figure(figsize=(7,7))
sns.heatmap(pd.DataFrame(volume_all).dropna().corr()[['eua']], vmin=-1, vmax= +1, annot=True, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 소결
# - EUA 가격은 직접적으로 가격을 추종하는 대상 ETF 금융상품(KEUA, KODex_eu, KRBN)의 가격과 상당히 밀접히 연관되어 있음
#     - 기타 친환경 상품 가격과의 상관관계는 어느 정도 존재함
#     - 거래량은 가격보다는 상관관계가 낮음
# - EUA가격에 대한 예측 모델은 다른 관련 종목의 거래에도 참고될 수 있음

# %% [markdown]
# # 1. 대상 etf 상품에 대한 quant 방법을 사용한 기본적인 수익률 계산

# %% [markdown]
# ### 1-0 일수익률의 정규 분포 확인

# %%
plt.figure(figsize =(15,45))
for i, carbon in enumerate(carbons):
    plt.subplot(10,2,i+1)
    plt.hist(carbon.Close.pct_change(),bins=100, color='gold')
    plt.title(cbns[i], fontsize =15)
    plt.grid(which='both')
    plt.xticks(rotation =30)
    
plt.subplots_adjust(left=0.12, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace= 1.25)

    
    
plt.show()

# %% [markdown]
# ### 1-1. 일 수익률 패턴 시각화

# %%
plt.figure(figsize =(15,40))
for i, carbon in enumerate(carbons):
    plt.subplot(10,2,i+1)
    plt.plot(carbon.Change)
    plt.title(cbns[i], fontsize =15)
    plt.axhline(0, color='red')
    plt.grid(which='both')
    plt.xticks(rotation =30)
    
plt.subplots_adjust(left=0.12, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace= 1.25)

    
plt.show()
# 전체

# %%
plt.figure(figsize =(15,45))
for i, carbon in enumerate(carbons):
    plt.subplot(10,2,i+1)
    plt.plot(carbon.Change[-60:])
    plt.title(cbns[i], fontsize=15)
    plt.axhline(0, color='red')
    plt.grid(which='both')
    plt.xticks(rotation =30)
    
plt.subplots_adjust(left=0.12, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace= 1.25)

    
plt.show()
# 최근 60일

# %% [markdown]
# ### 1-2. 누적수익률 패턴 시각화

# %%
for i, carbon in enumerate(carbons):
    for j in range(len(carbon)):
        carbon['return']= carbon.Close/carbon.Close[0]

# %%
plt.figure(figsize =(15,45))
for i, carbon in enumerate(carbons):
    plt.subplot(10,2,i+1)
    carbon['return'].plot(kind='area')
    plt.title(cbns[i], fontsize =15)
    plt.axhline(1, color='red')
    plt.grid(which='both')
    plt.xticks(rotation =30)
    
plt.subplots_adjust(left=0.12, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace= 1.25)

plt.show()

# %%
plt.figure(figsize =(10, 5))
return_all = {}
for i, carbon in enumerate(carbons):
    return_all[cbns[i]]= carbon.Close.iloc[-1]/carbon.Close.iloc[0]
plt.bar(return_all.keys(), return_all.values(), color = 'turquoise', alpha=0.7)
plt.axhline(1, color='red')
plt.grid(which='both')
plt.xticks(rotation =30)
plt.title('Return_CUM')    
plt.show()

# %%
plt.figure(figsize =(10, 5))
return_60 = {}
for i, carbon in enumerate(carbons):
    return_60[cbns[i]]= carbon.Close.iloc[-1]/carbon.Close.iloc[-60]
plt.bar(return_60.keys(), return_60.values(), alpha=0.7)
plt.axhline(1, color='red')
plt.grid(which='both')
plt.xticks(rotation =30)
plt.title('Return_CUM60')    
plt.show()

# %%
# eua.columns
# Out:
# Index(['Close', 'Open', 'High', 'Low', 'Volume', 'Change', 'return',
#        'return60'],
#       dtype='object')

# %%
# for i, carbon in enumerate(carbons):
#     print(carbon.columns)
# Out:
# Index(['Close', 'Open', 'High', 'Low', 'Volume', 'Change'], dtype='object')
# Index(['Close', 'Open', 'High', 'Low', 'Volume', 'Change'], dtype='object')
# Index(['Close', 'Open', 'High', 'Low', 'Volume', 'Change'], dtype='object')
# Index(['Close', 'Open', 'High', 'Low', 'Volume', 'Change'], dtype='object')
# Index(['Close', 'Open', 'High', 'Low', 'Volume', 'Change'], dtype='object')
# Index(['Close', 'Open', 'High', 'Low', 'Volume', 'Change'], dtype='object')
# Index(['Close', 'Open', 'High', 'Low', 'Volume', 'Change'], dtype='object')
# Index(['Close', 'Open', 'High', 'Low', 'Volume', 'Change'], dtype='object')
# Index(['Close', 'Open', 'High', 'Low', 'Volume', 'Change'], dtype='object')
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Change'], dtype='object')

# %% [markdown]
# ### 1-3. 5일 이동평균 및 20일 이동평균 시각화

# %%
# 전체 기간

# %%
plt.figure(figsize =(15,45))

for i, carbon in enumerate(carbons):
    plt.subplot(10,2,i+1)

    carbon['5m'] = carbon.Close.rolling(5).mean()
    carbon['20m'] = carbon.Close.rolling(20).mean()
    
    plt.plot(carbon['5m'], label ='5d' )
    plt.plot(carbon['20m'], label ='20d')

    plt.plot(carbon.Close, label = 'price_actual')

    plt.title(cbns[i], fontsize =15)
    plt.grid(which = 'both')
    plt.legend()
    plt.xticks(rotation =30)
    
plt.subplots_adjust(left=0.12, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace= 1.25)
plt.title('5/10D Rolling Average', fontsize ='18')
plt.show()

# %%
# 최근 60일

# %%
plt.figure(figsize =(10,50))

for i, carbon in enumerate(carbons):
    plt.subplot(10,1,i+1)

    carbon['5m60'] = carbon.Close[-60:].rolling(5).mean()
    carbon['20m60'] = carbon.Close[-60:].rolling(20).mean()
    
        
    plt.plot(carbon['5m60'], label ='5d60' )
    plt.plot(carbon['20m60'], label ='20d60')

    plt.plot(carbon.Close[-60:], label = 'price_actual')

    plt.title(cbns[i], fontsize =13)
    plt.grid(which = 'both')
    plt.legend()
    plt.xticks(rotation =30)
    
plt.subplots_adjust(left=0.12, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace= 0.5)

#plt.title('5/10D Rolling Average in Recent 60 days', fontsize ='15')
plt.show()

# %% [markdown]
# - orange = 20일 평균, blue = 5일 평균, grey =해당일 종가
# - 5일 이동평균이 20일 이동평균보다 커지는 지점: 매수 타이밍
# - 5일 이동평균이 20일 이동평균보다 작아지는 지점: 매도 타이밍

# %% [markdown]
# ### 1-4. MACD
# - Moving Average Convergence Divergence)
# - 신호, 평균, 확산을 통해 주가 추세의 강도, 방향, 모멤텀 및 지속 시간의 변화 표시
# - 상승기 : MACD가 signal 위에 있을 때
# - 하락기 : MACD가 signal 아래 있을 대
# - 매수신호: MACD가 signal선을 상향 돌파시(golden cross)
# - 매도신호: MACD가 signal선을 하향 돌파시(dead cross)

# %%
for i, carbon in enumerate(carbons):
    
    carbon['ema_short'] = carbon.Close.ewm(12).mean()
    carbon['ema_long'] = carbon.Close.ewm(26).mean()
    carbon['MACD'] = carbon['ema_short'] - carbon['ema_long']
    carbon['signal'] = carbon['MACD'].ewm(9).mean()
    carbon['macdhist'] = carbon['MACD'] - carbon['signal']

# %%
plt.figure(figsize =(20,100))

for i, carbon in enumerate(carbons):
#    plt.subplot(10,i+1)    
    carbon[['MACD', 'signal']].plot(figsize=(10,3))
    plt.axhline(0)
    plt.bar(carbon['macdhist'].index, carbon['macdhist'])

    plt.title(cbns[i])
    plt.grid()
    plt.show()
    
#plt.subplots_adjust(left=0.12, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace= 1.25)
#plt.title('MACD', fontsize ='18')
#plt.show()

# %%
plt.figure(figsize =(20,100))

for i, carbon in enumerate(carbons):
#    plt.subplot(10,1,i+1)    
    carbon[['MACD', 'signal']][-60:].plot(figsize=(10,3))
    plt.axhline(0)
    plt.bar(carbon['macdhist'][-60:].index, carbon['macdhist'][-60:])

    plt.title(cbns[i])
    plt.grid()
    plt.show()

# %% [markdown]
# - eua 추종 종목은 이제 막 매수신호(11월 초- 중반)를 넘어섰음
